# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
#  - Con el método ".read_csv()" se leerá cada uno de los archivos y se le específica el tipo de separador, ya que no es una "," (coma) sino un ";" (punto y coma).

# %%
# importar librerías
import pandas as pd
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames

#Archivo que contiene información de los pedidos:
df_instacart_orders=pd.read_csv("/datasets/instacart_orders.csv",sep=';')

#Archivo que contiene informacion de los productos:
df_products=pd.read_csv('/datasets/products.csv',sep=';')

#Archivo que contiene información de los productos pedidos en un pedido:
df_order_products=pd.read_csv('/datasets/order_products.csv',sep=';')

#Archivo que contiene información de las categorias del pasillo de viveres:
df_aisles=pd.read_csv('/datasets/aisles.csv',sep=';')

#Archivo que contiene informacion de los departamentos de viveres:
df_departments=pd.read_csv('/datasets/departments.csv',sep=';')

# %%
# mostrar información del DataFrame

#Información de los pedidos:
df_instacart_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame

#Información de los productos:
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# mostrar información del DataFrame

#Información de los productos pedidos:
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# mostrar información del DataFrame

#Información de los pasillos:
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# mostrar información del DataFrame

#Información de los departamentos:
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# ### **Conclusión:**
#
# #### El DataFrame "df_instacart_orders" tiene valores nulos en la columna "days_since_prior_order" y a su vez su tipo de variable es de tipo "float64", lo que deberia ser de tipo "int64", debido a que es una columna que almacena números de días transcurridos.
#
# #### El DataFrame "df_products" tiene valores nulos en la columna "product_name".
#
# #### El DataFrame "df_order_products" tiene valores nulos en la columna "add_to_cart_order" y a su vez su tipo de variable es de tipo "float64" que debería ser de tipo "int64", debido a que es una columna que almacena un orden secuencial (1,2,3,4,...).
#
#   - El resto de los DataFrame no contienen valores nulos.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Has cargado correctamente todos los archivos CSV y explorado su contenido con .info(), lo cual es un buen punto de partida para entender la estructura de los datos. También identificaste valores nulos y problemas de tipos de datos, lo que te permitirá corregirlos en la siguiente etapa de preprocesamiento.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
#   - Identificar duplicados y eliminarlos ya que generarán confución.
#   - Los valores nulos se pueden reemplazar por valores lógicos como la media o la mediana.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados

print("Número de valores duplicados:",df_instacart_orders.duplicated().sum())
print()

#DataFrame de los valores duplicados:
df_instacart_orders[df_instacart_orders.duplicated()]
# Out:
# Número de valores duplicados: 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# #### Respuesta:
#  - Todos los datos duplicados son del miercoles a las 2am

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

df_instacart_orders[(df_instacart_orders['order_dow']==3) & (df_instacart_orders['order_hour_of_day']==2) ]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# #### **Respuesta:**
# El resultado sugiere que, de 121 pedidos que se realizaron ese dia a esa hora, 15 son duplicados.

# %%
# Elimina los pedidos duplicados
df_instacart_orders.drop_duplicates(inplace=True)

# %%
# Vuelve a verificar si hay filas duplicadas
df_instacart_orders.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
df_instacart_orders['order_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# - Se halló que el día miercoles a las 2am se realizaron 121 pedidos de los cuales 15 eran pedidos duplicados. Se eliminaron los duplicados

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
df_products.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
df_products['department_id'].duplicated().sum()
# Out:
# 49673

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)

#Convirtiendo los nombres a mayúsculas:
df_products['product_name'].str.upper()

#Verificando los nombres duplicados:
df_products['product_name'].duplicated().sum()
# Out:
# 1257

# %%
# Revisa si hay nombres duplicados de productos no faltantes

#DataFrame con nombres de productos NO faltantes:
no_faltantes= df_products[~df_products['product_name'].isnull()]

#DataFrame duplicados con nombre de productos no faltantes:
no_faltantes['product_name'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# #### Hallazgos:
#   - En el DataFrame no hay filas duplicadas.
#   - La columna "department_id" tiene 49673 duplicas, lo que indica que los productos comparten departamentos.
#   - La columna "product_name" tiene 1257 duplicas y a su vez hay 0 duplicas de nombres de productos no faltantes. Es decir, los nombres duplicados son nulos.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_departments.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
df_departments['department_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# #### Hallazgos:
#   - En el DataFrame no hay filas duplicadas ni valores duplicados en las columnas. Esto quiere decir que para un Id hay un nombre de departamento.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
df_aisles['aisle_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# #### Hallazgos:
#   - En el DataFrame no hay filas duplicadas ni valores duplicados en las columnas. Esto quiere decir que para un Id hay un nombre de pasillo.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas

df_order_products.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso

oreder_id_dup= df_order_products['order_id'].duplicated().sum() #Duplicados de la columna 'order_id'
product_id_dup= df_order_products['product_id'].duplicated().sum() #Duplicados de la columna 'product_id'

print("Duplicados de la columna 'order_id':",oreder_id_dup)
print("Duplicados de la columna 'product_id':",product_id_dup)
# Out:
# Duplicados de la columna 'order_id': 4094961
# Duplicados de la columna 'product_id': 4499434

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#   - La columna "order_id" tiene 4094961 valores duplicados.
#   - La columna "product_id" tiene 4499434 valores duplicados

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'

df_products['product_name'].isnull().sum()
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
#   - Hay 1258 valores ausentes.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?

df_products[(df_products['product_name'].isnull())&(df_products['aisle_id']==100)].shape
# Out:
# (1258, 4)

# %% [markdown]
# Describe brDescribe brevemente cuáles son tus hallazgos.
#
#   - Todos los valores ausentes están relacionados con el pasillo con ID 100evemente cuáles son tus hallazgos.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
df_products[(df_products['product_name'].isnull())&(df_products['department_id']==21)].shape
# Out:
# (1258, 4)

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
#   - Todos los valores usentes están relacionados con el ID del departamento 21

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

print(df_departments[df_departments['department_id']==21]) #filtro del ID de departamento 21

print(df_aisles[df_aisles['aisle_id']==100]) #filtro del ID de aisle 100
# Out:
#     department_id department
# 20             21    missing
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
#   - Tanto el nombre de departamento como el nombre de aisle es "missing"

# %%
# Completa los nombres de productos ausentes con 'Unknown'

df_products['product_name'].fillna('Unknown',inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#   - Los nombres de los productos ausentes se cambiaron por "Unknown"

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
df_instacart_orders.isnull().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?

df_instacart_orders[(~df_instacart_orders['order_number']==1) & df_instacart_orders['days_since_prior_order' ].isnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#   - Los valores ausentes están relacionados con el primer pedido del cliente. Es decir, el número de pedido que es diferente a 1 no tiene valores nulos en la columna "day_since_prior_order"

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
df_order_products.isnull().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?

print("Valor mínimo:",df_order_products['add_to_cart_order'].min())

print("Valor máximo:",df_order_products['add_to_cart_order'].max())
# Out:
# Valor mínimo: 1.0
# Valor máximo: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
#   - La columna "add_to_cart_order" indica el orden en el que un cliente añade un articulo al carrito. El orden máximo es 64 y el mínimo 1

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'

#Dataframe de los IDs de pedidos que tienen valor ausente en 'add_to_cart_order':
id_productos_ausentes = df_order_products[ df_order_products['add_to_cart_order'].isnull() ] ['order_id']

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

df_order_products.groupby(id_productos_ausentes)['product_id'].count().min()
# Out:
# 1

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
#   - Ningún pedido con valores ausentes tiene más de 64 productos y la cantidad mínima que tiene un pedido con valores ausentes es 1.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.

df_order_products['add_to_cart_order'].fillna(999,inplace=True)
df_order_products['add_to_cart_order']=df_order_products['add_to_cart_order'].astype(int)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# #### Se hallaron valores ausentes en la columna "_add_to_cart_order_" y se realizó lo siguiente:
#
#   - Se filtraron los IDs de los pedidos con valores nulos en el orden y se contaron la cantidad de productos que tiene cada pedido con valores ausentes, en los cuales hay un minimo de 1 producto por pedido.
#
#   - Se reemplazaron los valores nulos por el número 999 y se le cambió el tipo de dato a la columna "_add_to_cart_order_" de "float64" a "int64".

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
#     1. En el Dataframe "df_instacart_orders" se hayaron filas duplidas y valores ausentes en la columna "days_since_prior_order". Las filas duplicadas se eliminaron y se observó que los valores ausentes en dicha columna están relacionados con el número de pedidos de un cliente. Si, el pedido de un cliente es el primero ("order_number"=1) el valor de los días es ausente ("days_since_prior_order" = NaN).
#
#     2. En el Dataframe "df_products" no se encontraron filas duplicadas. Aunque, en la columna "product_name" sí; además se observó que dichos valores duplicados corresponden a valores ausentes, los cuales se reemplazaron por "Unknown". También, se hayaron valores duplicados en la columna "department_id", pero, estos duplicados representan que los productos comparten departamento.
#
#     3. En el Dataframe "df_order_products" se hayaron valores duplicados en las columnas "order_id" y "product_id", estos valores representan que un producto puede estar en varios pedidos y que un pedido puede tener varios productos, ya que este Dataframe representa los productos pedidos en un pedido. Además, se hayaron valores nulos en la columna "add_to_cart_order" los cuales se reemplazaron por el valor 999 y el tipo de dato de dicha columna se cambió del tipo "float64" al tipo "int64".

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Muy buen trabajo en la limpieza de datos. Identificaste y eliminaste duplicados correctamente, y aplicaste estrategias lógicas para manejar valores nulos. También realizaste conversiones de tipos de datos adecuadas, asegurando que las columnas como add_to_cart_order y days_since_prior_order tuvieran los tipos correctos.
#
# </div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
#Verificar que "order_hour_of_day" esté entre 0 y 23:
print("Valor mínimo:",df_instacart_orders['order_hour_of_day'].min())
print("Valor máximo:",df_instacart_orders['order_hour_of_day'].max())
# Out:
# Valor mínimo: 0
# Valor máximo: 23

# %%
print("Valor mínimo:",df_instacart_orders['order_dow'].min())
print("Valor máximo:",df_instacart_orders['order_dow'].max())
# Out:
# Valor mínimo: 0
# Valor máximo: 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
#   - Los valores de las columnas se encuentran dentro de los valores adecuados

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
#Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.

df_instacart_orders['order_hour_of_day'].plot(kind='hist',bins=24,title='Pedidos según la hora del dia',
                                             xlabel='Hora del dia',color='pink')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
#  - La mayor cantidad de ordenes se realizan alrededor de las 10am

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
#Crea un gráfico que muestre qué día de la semana la gente hace sus compras.

df_instacart_orders['order_dow'].plot(kind='hist',
          title='Pedidos según el dia',color='red',xlabel='Dia de la semana')


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
#  - Las personas compran todos los dias, pero el dia en el que más compran es el dia domingo.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
#Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, 
#y comenta sobre los valores mínimos y máximos.
    
df_instacart_orders['days_since_prior_order'].plot(kind='hist',bins=30,
                                                   xlabel='Cantidad de dias',
                                                   title='Tiempo de espera')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
#  - La mayoría de las personas esperan 30 días para volver a comprar.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> ✅ - En esta sección, se verificaron correctamente los valores esperados para `order_hour_of_day` y `order_dow`. También se generaron gráficos adecuados para analizar tendencias en pedidos según la hora del día, el día de la semana y el tiempo de espera entre pedidos.
#
# ### **✅ Preguntas respondidas correctamente:**
# ✔️ **[A1]** Se verificó que los valores en `order_hour_of_day` y `order_dow` estén dentro de los rangos esperados.
# ✔️ **[A2]** Se creó un gráfico que muestra la cantidad de pedidos por hora del día y se identificó que el mayor número de pedidos ocurre alrededor de las 10 AM.
# ✔️ **[A3]** Se generó un gráfico que muestra los pedidos por día de la semana, encontrando que el día con más pedidos es el domingo.
# ✔️ **[A4]** Se graficó el tiempo de espera entre pedidos y se concluyó que la mayoría de los clientes esperan 30 días para volver a hacer una compra.
#
# ⚠️ **Sugerencia:**
# 🔹 En los gráficos, sería útil agregar etiquetas a los ejes (`xlabel`, `ylabel`) para mejorar la legibilidad.
# 🔹 Usar `barplot()` de Seaborn en lugar de `histplot()` para `order_dow`, ya que `order_dow` representa categorías discretas (días de la semana) en lugar de valores continuos.
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
#¿Existe alguna diferencia entre las distribuciones 'order_hour_of_day' de los miércoles y los sábados? 
#Traza gráficos de barra de 'order_hour_of_day' para ambos días en la misma figura y describe las diferencias que observes.

#filtro para los dias:
miercoles=df_instacart_orders[df_instacart_orders['order_dow']==3]
sabado=df_instacart_orders[df_instacart_orders['order_dow']==6]

# %%
#gráfica 1:
miercoles['order_hour_of_day'].plot(kind='hist',alpha=0.6,title='Distribuciones para miercoles y sabado',
                                    xlabel='Horas del dia',ylabel='Distribución',bins=24)
#gráfica 2:
sabado['order_hour_of_day'].plot(kind='hist',alpha=0.6,bins=24)
plt.legend(['Miercoles','Sabado'])

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
#  - La diferencia entre los dias miercoles y sabado no es tan notable, lo que da a entender que en ambos dias muchos clientes hacen sus pedidos.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
#Grafica la distribución para el número de órdenes que hacen los clientes 
#(es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).


df_instacart_orders['order_number'].plot(kind='hist',bins=50,
                                         xlabel='Número de orden',ylabel='Cantidad de pedidos',
                                         title='Cantidad de pedidos según en número de orden')


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
#  - La mayoria de los pedidos lo realizan los clientes que sus número de ordenes son 1, 2 o 3.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
df_order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440                 17          0
# 1    567889        1560                  1          1
# 2   2261212       26683                  1          1
# 3    491251        8670                 35          1
# 4   2571142        1940                  5          1

# %%
#Agrupando los datos segun el id de los productos y contar:
populares=df_order_products.groupby('product_id')['product_id'].count()

populares=populares.reset_index(name='cantidad')

#Ordenando los datos por la cantidad de manera descendente:
populares=populares.sort_values(by='cantidad',ascending=False)

populares=populares.reset_index(drop=True)

#Guardando solo los 20 productos más populares:
populares=populares.head(20)

# %%
#concatenando los dos DataFrame:
productos_20=populares.merge(df_products,on='product_id',how='left')

#Imprimir solo el 'product_id' y 'product_name':
print(productos_20.loc[:,['product_id','product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        47626               Large Lemon
# 7        16797              Strawberries
# 8        26209                     Limes
# 9        27845        Organic Whole Milk
# 10       27966       Organic Raspberries
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       39275       Organic Blueberries
# 15       49683            Cucumber Kirby
# 16       28204        Organic Fuji Apple
# 17        5876             Organic Lemon
# 18        8277  Apple Honeycrisp Organic
# 19       40706    Organic Grape Tomatoes

# %% [markdown]
# Escribe aquí tus conclusiones
#  - El producto con mayor venta es: Banana

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> ✅ - Se exploraron las diferencias en la distribución de pedidos por hora entre miércoles y sábados, la cantidad de pedidos por cliente y los productos más populares. Se realizaron gráficos apropiados para visualizar estas tendencias.
#
# ### **✅ Preguntas respondidas correctamente:**
# ✔️ **[B1]** Se comparó la distribución de `order_hour_of_day` entre miércoles y sábados, concluyendo que las diferencias no son significativas.
# ✔️ **[B2]** Se generó un gráfico de distribución del número de pedidos por cliente, mostrando que la mayoría de los clientes hacen entre 1 y 3 pedidos.
# ✔️ **[B3]** Se identificaron correctamente los 20 productos más populares, destacando que el producto con más ventas es la **Banana**.
#
# ⚠️ **Sugerencia:**
# 🔹 Para la comparación entre miércoles y sábados, en lugar de usar `histplot()`, un `barplot()` permitiría visualizar mejor las diferencias entre las horas del día.
# 🔹 Para la distribución del número de pedidos por cliente, un gráfico de barras (`sns.countplot()`) ayudaría a mostrar la cantidad de clientes en cada categoría de pedidos de forma más clara.
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
#¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?

#Agrupando por 'order_id' y contando los 'product_id', se reinician los índices:
compras=df_order_products.groupby(['order_id'])['product_id'].count().reset_index(name='cant_articulos')

#Mostrando los primeros 10 elementos:
compras.head(10)
# Out:
#    order_id  cant_articulos
# 0         4              13
# 1         9              15
# 2        11               5
# 3        19               3
# 4        20               8
# 5        31              10
# 6        48               8
# 7        56              10
# 8        61              12
# 9        68               9

# %%
#Graficando la cantidad de los articulos que compra un cliente en cada pedido:
compras['cant_articulos'].plot(kind='hist',bins=100,
                              title='Articulos que compran en un pedido',
                              xlabel='Cantidad de articulos')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#  - La mayoria de los clientes suelen comprar entre 1 y 4 articulos en un pedido

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
#¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia
#(muestra sus nombres e IDs de los productos)?

#Filtro de los productos donde 'reodered'==1 (Significa que ya el cliente lo había pedido antes):
prod_repetidos=df_order_products[df_order_products['reordered']==1]

#Agrupación de los datos mediante 'product_id' y se cuentan las veces que se pidieron los articulos:
prod_frecuentes=prod_repetidos.groupby('product_id')['order_id'].count().reset_index(name='cant_frecuentes')

#Ordenar los valores según la cantidad y a su vez guardar los 20 articulos más frecuentes:
prod_frecuentes=prod_frecuentes.sort_values(by='cant_frecuentes',ascending=False).head(20)

#Reiniciar los índices:
prod_frecuentes=prod_frecuentes.reset_index(drop=True)

#Mostrando los 20 artículos más vendidos:
prod_frecuentes.head(20)
# Out:
#     product_id  cant_frecuentes
# 0        24852            55763
# 1        13176            44450
# 2        21137            28639
# 3        21903            26233
# 4        47209            23629
# 5        47766            18743
# 6        27845            16251
# 7        47626            15044
# 8        27966            14748
# 9        16797            13945
# 10       26209            13327
# 11       22935            11145
# 12       24964            10411
# 13       45007            10076
# 14       49683             9538
# 15       28204             8989
# 16        8277             8836
# 17       39275             8799
# 18        5876             8412
# 19       49235             8389

# %%
#Combinar los DataFrames prod_frecuentes con df_products mediante la columna 'product_id':
articulos_frecuentes=prod_frecuentes.merge(df_products,on='product_id',how='left')

#articulos_frecuentes
#Imprimir solo las columnas 'product_id' y 'product_name':
print(articulos_frecuentes.loc[:,['product_id','product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        27845        Organic Whole Milk
# 7        47626               Large Lemon
# 8        27966       Organic Raspberries
# 9        16797              Strawberries
# 10       26209                     Limes
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       49683            Cucumber Kirby
# 15       28204        Organic Fuji Apple
# 16        8277  Apple Honeycrisp Organic
# 17       39275       Organic Blueberries
# 18        5876             Organic Lemon
# 19       49235       Organic Half & Half

# %% [markdown]
# Escribe aquí tus conclusiones
#  -

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
#Para cada producto, ¿cuál es la tasa de repetición del pedido 
#(número de repeticiones de pedido/total de pedidos?

#total de productos:
#Agrupación por la columna 'order_id' y se cuenta las veces que aparece el pedido :
#repeticion del pedido por producto:
repeticiones_pedidos=df_order_products.groupby('product_id')['order_id'].count().reset_index(name='repeticiones_pedido')
print(repeticiones_pedidos)

#el total de pedidos va a ser el número de filas del DataFrame:
total_productos=repeticiones_pedidos.shape[0]
total_productos
# Out:
#        product_id  repeticiones_pedido
# 0               1                  280
# 1               2                   11
# 2               3                   42
# 3               4                   49
# 4               7                    2
# ...           ...                  ...
# 45568       49690                    5
# 45569       49691                   72
# 45570       49692                   12
# 45571       49693                   25
# 45572       49694                    9
#
# [45573 rows x 2 columns]
# 45573

# %%
#calculando la tasa de repeticion:
tasa_repeticion=repeticiones_pedidos['repeticiones_pedido']/total_productos

tasa_repeticion.head(10)
# Out:
# 0    0.006144
# 1    0.000241
# 2    0.000922
# 3    0.001075
# 4    0.000044
# 5    0.000417
# 6    0.000461
# 7    0.007395
# 8    0.000351
# 9    0.000900
# Name: repeticiones_pedido, dtype: float64

# %%
#creación de la tabla de las proporciones
df_proporcion=repeticiones_pedidos.merge(df_products,on='product_id',how='left')

#Agregar una nueva columna con las proporciones de los pedidos:
df_proporcion['proporcion']=tasa_repeticion

#eliminar las columnas innecesarias:
df_proporcion.drop(['aisle_id','department_id','repeticiones_pedido'],axis='columns',inplace=True)

#se ordenó el DataFrame de manera descendente (opcional, para visualizar mejor los datos )
df_proporcion.sort_values(by='proporcion',ascending=False)
# Out:
#        product_id                                       product_name  \
# 22808       24852                                             Banana
# 12025       13176                             Bag of Organic Bananas
# 19370       21137                               Organic Strawberries
# 20077       21903                               Organic Baby Spinach
# 43271       47209                               Organic Hass Avocado
# ...           ...                                                ...
# 5339         5836                       Arctic D Cod Liver Oil Lemon
# 39932       43573                                     Whisk- 10 Inch
# 39930       43570                                       Queso Cotija
# 33181       36174                                  Whole Pinto Beans
# 37938       41403  Extra Rich & Thick Spaghetti Sauce Spices & Se...
#
#        proporcion
# 22808    1.449323
# 12025    1.169486
# 19370    0.812740
# 20077    0.745419
# 43271    0.653303
# ...           ...
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#  - Con esta tabla se demuestra que los articulos más pedidos en las tablas anteriores son los que tienen las tasas de proporción más altas.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
#Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? 
#Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.


df_pedidos =df_instacart_orders.merge(df_order_products,on='order_id',how='right')

df_pedidos.groupby('user_id')['reordered'].mean()
# Out:
# user_id
# 2         0.038462
# 4         0.000000
# 5         0.666667
# 6         0.000000
# 7         0.928571
#             ...
# 206203    0.222222
# 206206    0.714286
# 206207    0.891304
# 206208    0.696000
# 206209    0.320000
# Name: reordered, Length: 149626, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
#¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos 
#(muestra las IDs de los productos, sus nombres,
#y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %%
principales_products=df_order_products[df_order_products.add_to_cart_order==1][['product_id','add_to_cart_order']].groupby('product_id').count()
principales_products.reset_index(inplace=True)
principales_products=principales_products.sort_values(by='add_to_cart_order',ascending=False).head(20)

principales_products=principales_products.merge(df_products,on='product_id',how='left')[['product_id','product_name','add_to_cart_order']]
principales_products.rename(columns={'add_to_cart_order':'numero_veces'})
# Out:
#     product_id                 product_name  numero_veces
# 0        24852                       Banana         15562
# 1        13176       Bag of Organic Bananas         11026
# 2        27845           Organic Whole Milk          4363
# 3        21137         Organic Strawberries          3946
# 4        47209         Organic Hass Avocado          3390
# 5        21903         Organic Baby Spinach          3336
# 6        47766              Organic Avocado          3044
# 7        19660                 Spring Water          2336
# 8        16797                 Strawberries          2308
# 9        27966          Organic Raspberries          2024
# 10       44632   Sparkling Water Grapefruit          1914
# 11       49235          Organic Half & Half          1797
# 12       47626                  Large Lemon          1737
# 13         196                         Soda          1733
# 14       38689     Organic Reduced Fat Milk          1397
# ...

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> ✅ - Se analizaron correctamente las tendencias de compra más avanzadas, como la cantidad de artículos por pedido, los productos más reordenados, la tasa de repetición de pedidos por producto y por cliente, y los productos agregados primero al carrito.
#
# ### **✅ Preguntas respondidas correctamente:**
# ✔️ **[C1]** Se analizó cuántos artículos suelen comprar las personas en un pedido, encontrando que la mayoría compra entre 1 y 4 artículos.
# ✔️ **[C2]** Se identificaron los 20 productos más frecuentemente reordenados.
# ✔️ **[C3]** Se calculó la tasa de repetición de pedidos por producto, mostrando que los productos más pedidos tienen las tasas más altas.
# ✔️ **[C4]** Se calculó la tasa de repetición de pedidos por cliente, lo que permite evaluar la lealtad de los consumidores a ciertos productos.
# ✔️ **[C5]** Se identificaron los 20 productos que más frecuentemente fueron los primeros en agregarse al carrito.
#
# ⚠️ **Sugerencia:**
# 🔹 Para la tasa de repetición de pedidos por producto y por cliente, un gráfico de densidad (`sns.kdeplot()`) podría ayudar a visualizar mejor la distribución de las tasas.
# 🔹 Para los artículos agregados primero al carrito, ordenar los productos por frecuencia y graficarlos con `barplot()` facilitaría la interpretación de los resultados.
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %%
#- Los productos que más se venden y que son los primeros en elegir los clientes son: Banana y Bag of Organic Bananas.
#- Los dias en los que las personas realizan más pedidos son los dias: domingos y lunes
#- Las horas en las que los clientes más realizan pedidos est
# Out:
#   Cell In[111], line 1
#     - Los productos que más se venden y que son los primeros en elegir los clientes son: Banana y Bag of Organic Bananas.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # **Comentario Final del Revisor**
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# 🎉 **¡Felicidades! Tu proyecto está aprobado.** 🎉
#
# Has hecho un excelente trabajo analizando los datos de Instacart. Tu preprocesamiento es sólido, las visualizaciones son adecuadas y las conclusiones están bien fundamentadas. Se nota que tienes un buen manejo de los datos y de las herramientas de análisis en Python.
#
# ### **🔹 Consejos para futuros proyectos:**
# ✅ **Mejora la presentación de los gráficos:** Usa etiquetas en los ejes y considera `barplot()` en lugar de `histplot()` para variables categóricas.
# ✅ **Usa Markdown para la conclusión:** Esto hará que tu reporte sea más claro y legible.
# ✅ **Haz un Kernel Restart antes de enviar el proyecto:** Asegúrate de que todo se ejecuta correctamente desde el inicio para evitar errores ocultos.
# ✅ **Incluye más interpretación de los gráficos:** Describe tendencias y posibles implicaciones de los hallazgos para que tu análisis sea más impactante.
#
# 🔥 **¡Sigue así! Con un poco más de enfoque en la presentación, tu trabajo pasará de bueno a excelente.** 🚀💪
# </div>
